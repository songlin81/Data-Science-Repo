# %%
# loc - (Mean) where the peak of the bell exists.
# scale - (Standard Deviation) how flat the graph distribution should be.
# size - The shape of the returned array.

# %%
from numpy import random
x = random.normal(size=(2, 3))
print(x)
# Out:
# [[-1.38232865 -1.20183771 -0.12779239]
#  [ 0.46283746 -0.28588913 -0.12482922]]

# %%
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# [[ 3.30580398  2.2785406   3.35112513]
#  [ 3.68600302  1.32925229 -3.84517091]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000), hist=False)
plt.show()

# %%
x = random.normal(size=(2, 3))
print(x)
print(x.flatten())
# Out:
# [[ 0.10939114 -2.06122639  1.65685942]
#  [ 0.26628723  1.64691817 -0.94539415]]
# [ 0.10939114 -2.06122639  1.65685942  0.26628723  1.64691817 -0.94539415]

# %%
sns.distplot(x.flatten(), hist=False)
plt.show()
